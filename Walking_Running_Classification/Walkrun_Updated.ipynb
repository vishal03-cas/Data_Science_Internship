# %%
import pandas as pd  
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('walkrun.csv')
df
# Out:
#             date                time username  wrist  activity  \
# 0      2017-6-30  13:51:15:847724020   viktor      0         0
# 1      2017-6-30  13:51:16:246945023   viktor      0         0
# 2      2017-6-30  13:51:16:446233987   viktor      0         0
# 3      2017-6-30  13:51:16:646117985   viktor      0         0
# 4      2017-6-30  13:51:16:846738994   viktor      0         0
# ...          ...                 ...      ...    ...       ...
# 88583   2017-7-9   20:9:15:317911028   viktor      0         0
# 88584   2017-7-9   20:9:15:517889022   viktor      0         0
# 88585   2017-7-9   20:9:15:717828989   viktor      0         0
# 88586   2017-7-9   20:9:15:917932987   viktor      0         0
# 88587   2017-7-9   20:9:16:117410004   viktor      0         0
#
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0              0.2650         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# ...

# %%
df.head()
# Out:
#         date                time username  wrist  activity  acceleration_x  \
# 0  2017-6-30  13:51:15:847724020   viktor      0         0          0.2650
# 1  2017-6-30  13:51:16:246945023   viktor      0         0          0.6722
# 2  2017-6-30  13:51:16:446233987   viktor      0         0          0.4399
# 3  2017-6-30  13:51:16:646117985   viktor      0         0          0.3031
# 4  2017-6-30  13:51:16:846738994   viktor      0         0          0.4814
#
#    acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4         -0.9312          0.0359  0.0527  0.4379  2.4922

# %%
df.tail()
# Out:
#            date               time username  wrist  activity  acceleration_x  \
# 88583  2017-7-9  20:9:15:317911028   viktor      0         0          0.3084
# 88584  2017-7-9  20:9:15:517889022   viktor      0         0          0.4977
# 88585  2017-7-9  20:9:15:717828989   viktor      0         0          0.4587
# 88586  2017-7-9  20:9:15:917932987   viktor      0         0          0.2590
# 88587  2017-7-9  20:9:16:117410004   viktor      0         0          0.3140
#
#        acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 88583         -0.8376         -0.1327  0.4823  2.0124  0.6048
# 88584         -1.0027         -0.4397  0.1022 -1.2565 -0.0761
# 88585         -1.1780         -0.2827 -1.4500 -0.2792 -1.2616
# 88586         -0.8582         -0.0759 -1.5165  0.4560 -1.7755
# 88587         -0.8008         -0.0911  0.1183  1.0850  1.2814

# %%
df.shape
# Out:
# (88588, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88588 entries, 0 to 88587
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            88588 non-null  object
#  1   time            88588 non-null  object
#  2   username        88588 non-null  object
#  3   wrist           88588 non-null  int64
#  4   activity        88588 non-null  int64
#  5   acceleration_x  88588 non-null  float64
#  6   acceleration_y  88588 non-null  float64
#  7   acceleration_z  88588 non-null  float64
#  8   gyro_x          88588 non-null  float64
#  9   gyro_y          88588 non-null  float64
#  10  gyro_z          88588 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 7.4+ MB

# %%
df.describe()
# Out:
#               wrist      activity  acceleration_x  acceleration_y  \
# count  88588.000000  88588.000000    88588.000000    88588.000000
# mean       0.522170      0.500801       -0.074811       -0.562585
# std        0.499511      0.500002        1.009299        0.658458
# min        0.000000      0.000000       -5.350500       -3.299000
# 25%        0.000000      0.000000       -0.381800       -1.033500
# 50%        1.000000      1.000000       -0.059500       -0.759100
# 75%        1.000000      1.000000        0.355500       -0.241775
# max        1.000000      1.000000        5.603300        2.668000
#
#        acceleration_z        gyro_x        gyro_y        gyro_z
# count    88588.000000  88588.000000  88588.000000  88588.000000
# mean        -0.313956      0.004160      0.037203      0.022327
# std          0.486815      1.253423      1.198725      1.914423
# min         -3.753800     -4.430600     -7.464700     -9.480000
# ...

# %% [markdown]
# #### --Here you can see that wrist has 0.522 mean and activity has 0.500 mean that indicate that data is perfectaly balance
# #### --Here you can see that gyzo_z has range from -9.480 to 11.26 with a high standard deviation(1.914)
# #### --Here you can see that gyro_x,gyro_y and gyro_z has median value near 0;

# %%
df.isnull().sum()
# Out:
# date              0
# time              0
# username          0
# wrist             0
# activity          0
# acceleration_x    0
# acceleration_y    0
# acceleration_z    0
# gyro_x            0
# gyro_y            0
# gyro_z            0
# dtype: int64

# %% [markdown]
# #### --Here you can see that there is not any null value

# %%
df = df.drop(['date','time','username','wrist'],axis=1)

# %%
df
# Out:
#        activity  acceleration_x  acceleration_y  acceleration_z  gyro_x  \
# 0             0          0.2650         -0.7814         -0.0076 -0.0590
# 1             0          0.6722         -1.1233         -0.2344 -0.1757
# 2             0          0.4399         -1.4817          0.0722 -0.9105
# 3             0          0.3031         -0.8125          0.0888  0.1199
# 4             0          0.4814         -0.9312          0.0359  0.0527
# ...         ...             ...             ...             ...     ...
# 88583         0          0.3084         -0.8376         -0.1327  0.4823
# 88584         0          0.4977         -1.0027         -0.4397  0.1022
# 88585         0          0.4587         -1.1780         -0.2827 -1.4500
# 88586         0          0.2590         -0.8582         -0.0759 -1.5165
# 88587         0          0.3140         -0.8008         -0.0911  0.1183
#
#        gyro_y  gyro_z
# 0      0.0325 -2.9296
# 1      0.0208  0.1269
# 2      0.1063 -2.4367
# ...

# %% [markdown]
# #### -- Deleted some unwanted columns

# %%
df.columns
# Out:
# Index(['activity', 'acceleration_x', 'acceleration_y', 'acceleration_z',
#        'gyro_x', 'gyro_y', 'gyro_z'],
#       dtype='object')

# %%
plt.figure(figsize=(25,25),facecolor='white')
plot_num = 1

for column in df:
    if plot_num <=8:
        plt.subplot(3,3,plot_num)
        sns.histplot(df[column],kde=True,color='green')
        plt.xlabel(column,fontsize=25)
        plt.ylabel('count',fontsize=20)
        plt.xticks(fontsize=15)
        plt.yticks(fontsize=15)
    plot_num = plot_num+1
plt.tight_layout()

# %%
sns.boxplot(x=df.acceleration_x)
# Out:
# <Axes: xlabel='acceleration_x'>

# %%
np.median(df.acceleration_x)
# Out:
# -0.0595

# %%
df.loc[(df['acceleration_x']< -1.0) | (df['acceleration_x']>1.0),'acceleration_x']
# Out:
# 755      1.2842
# 757      1.0601
# 759      1.0069
# 761      1.5466
# 763      1.3669
#           ...
# 87731    1.8530
# 87733    1.4518
# 87737    1.4954
# 87752    2.5963
# 87754    2.2590
# Name: acceleration_x, Length: 16247, dtype: float64

# %%
df.loc[(df['acceleration_x']< -1.0) | (df['acceleration_x']>1.0),'acceleration_x'] = -0.0595

# %%
sns.boxplot(x=df.acceleration_x)
# Out:
# <Axes: xlabel='acceleration_x'>

# %%
sns.boxplot(x=df.acceleration_y)
# Out:
# <Axes: xlabel='acceleration_y'>

# %%
np.median(df.acceleration_y)
# Out:
# -0.7591

# %%
df.loc[(df['acceleration_y'] < -1.1) | (df['acceleration_y'] > 0.9),'acceleration_y'] = -0.7591

# %%
sns.boxplot(x=df.acceleration_y)
# Out:
# <Axes: xlabel='acceleration_y'>

# %%
sns.boxplot(x = df.acceleration_z)
# Out:
# <Axes: xlabel='acceleration_z'>

# %%
np.median(df.acceleration_z)
# Out:
# -0.221

# %%
df.loc[(df['acceleration_z'] < -0.5) | (df['acceleration_z'] > 0.3),'acceleration_z'] = -0.221

# %%
sns.boxplot(x = df.acceleration_z)
# Out:
# <Axes: xlabel='acceleration_z'>

# %%
sns.boxplot(x = df.gyro_x)
# Out:
# <Axes: xlabel='gyro_x'>

# %%
np.median(df.gyro_x)
# Out:
# 0.0187

# %%
df.loc[(df['gyro_x'] < -2) | (df['gyro_x'] > 2),'gyro_x'] = 0.0187

# %%
sns.boxplot(x = df.gyro_x)
# Out:
# <Axes: xlabel='gyro_x'>

# %%
sns.boxplot(x = df.gyro_y)
# Out:
# <Axes: xlabel='gyro_y'>

# %%
np.median(df.gyro_y)
# Out:
# 0.0393

# %%
df.loc[(df['gyro_y'] < -2 ) | (df['gyro_y'] > 2),'gyro_y'] =  0.0393

# %%
sns.boxplot(x = df.gyro_y)
# Out:
# <Axes: xlabel='gyro_y'>

# %%
sns.boxplot(x = df.gyro_z)
# Out:
# <Axes: xlabel='gyro_z'>

# %%
np.median(df.gyro_z)
# Out:
# 0.0069

# %%
df.loc[(df['gyro_z'] < -0.3) | (df['gyro_z'] > 3),'gyro_z'] = 0.0069

# %%
sns.boxplot(x = df.gyro_z)
# Out:
# <Axes: xlabel='gyro_z'>

# %% [markdown]
# #### - Here we have checked one by one outliers in columns and remove it

# %% [markdown]
# ### We are checking co-relation between columns

# %%
df.corr()
# Out:
#                 activity  acceleration_x  acceleration_y  acceleration_z  \
# activity        1.000000        0.122363        0.613206        0.246845
# acceleration_x  0.122363        1.000000        0.057482       -0.063737
# acceleration_y  0.613206        0.057482        1.000000        0.050527
# acceleration_z  0.246845       -0.063737        0.050527        1.000000
# gyro_x          0.053417       -0.060336       -0.072562       -0.069939
# gyro_y         -0.043971        0.003581        0.029497       -0.033624
# gyro_z         -0.006551        0.055282        0.013368        0.039364
#
#                   gyro_x    gyro_y    gyro_z
# activity        0.053417 -0.043971 -0.006551
# acceleration_x -0.060336  0.003581  0.055282
# acceleration_y -0.072562  0.029497  0.013368
# acceleration_z -0.069939 -0.033624  0.039364
# gyro_x          1.000000  0.000211  0.036622
# gyro_y          0.000211  1.000000  0.186756
# gyro_z          0.036622  0.186756  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### There is no highly co-related columns in given columns so we can not remove any column

# %%
df
# Out:
#        activity  acceleration_x  acceleration_y  acceleration_z  gyro_x  \
# 0             0          0.2650         -0.7814         -0.0076 -0.0590
# 1             0          0.6722         -0.7591         -0.2344 -0.1757
# 2             0          0.4399         -0.7591          0.0722 -0.9105
# 3             0          0.3031         -0.8125          0.0888  0.1199
# 4             0          0.4814         -0.9312          0.0359  0.0527
# ...         ...             ...             ...             ...     ...
# 88583         0          0.3084         -0.8376         -0.1327  0.4823
# 88584         0          0.4977         -1.0027         -0.4397  0.1022
# 88585         0          0.4587         -0.7591         -0.2827 -1.4500
# 88586         0          0.2590         -0.8582         -0.0759 -1.5165
# 88587         0          0.3140         -0.8008         -0.0911  0.1183
#
#        gyro_y  gyro_z
# 0      0.0325  0.0069
# 1      0.0208  0.1269
# 2      0.1063  0.0069
# ...

# %%
# Check for imbalance in the target variable
print(df['activity'].value_counts())
sns.countplot(x='activity', data=df)
plt.xlabel("Activity (0=Walking, 1=Running)")
plt.title('Class Distribution')
plt.show()
# Out:
# activity
# 1    44365
# 0    44223
# Name: count, dtype: int64

# %%
X = df.drop(columns = ['activity'])
y = df['activity']

# %%
X
# Out:
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0              0.2650         -0.7814         -0.0076 -0.0590  0.0325  0.0069
# 1              0.6722         -0.7591         -0.2344 -0.1757  0.0208  0.1269
# 2              0.4399         -0.7591          0.0722 -0.9105  0.1063  0.0069
# 3              0.3031         -0.8125          0.0888  0.1199 -0.4099  0.0069
# 4              0.4814         -0.9312          0.0359  0.0527  0.4379  2.4922
# ...               ...             ...             ...     ...     ...     ...
# 88583          0.3084         -0.8376         -0.1327  0.4823  0.0393  0.6048
# 88584          0.4977         -1.0027         -0.4397  0.1022 -1.2565 -0.0761
# 88585          0.4587         -0.7591         -0.2827 -1.4500 -0.2792  0.0069
# 88586          0.2590         -0.8582         -0.0759 -1.5165  0.4560  0.0069
# 88587          0.3140         -0.8008         -0.0911  0.1183  1.0850  1.2814
#
# [88588 rows x 6 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 88583    0
# 88584    0
# 88585    0
# 88586    0
# 88587    0
# Name: activity, Length: 88588, dtype: int64

# %% [markdown]
# ## Apply the   train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=33)

# %%
X_train
# Out:
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 15668         -0.0595         -0.3383          0.0749  1.7012  0.9477  1.6725
# 2310          -0.0595         -0.7591         -0.2210 -0.6959  0.0393  0.0069
# 23428         -0.1645         -1.0490         -0.1887 -1.1104  0.2635  1.1123
# 84090         -0.0595         -0.7591         -0.2210  0.3708 -1.1406  0.0069
# 6281          -0.3613         -1.0440         -0.2045 -1.4536 -0.9135  1.5003
# ...               ...             ...             ...     ...     ...     ...
# 65593         -0.0595         -0.8423         -0.2210 -0.7321 -0.5354  0.0069
# 27849         -0.4028         -0.7081         -0.3360  0.7767  0.0393 -0.2818
# 578            0.4759         -0.8437         -0.2073  0.4256  0.7942  0.6932
# 67975          0.2760         -0.7591         -0.3695  1.0080 -0.9392  0.8337
# 23572         -0.4233         -0.8777         -0.1386 -0.1115  1.6802  0.6823
#
# [70870 rows x 6 columns]

# %%
X_test
# Out:
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 36773         -0.4066         -0.9759         -0.3365  0.7538 -0.1859  0.0069
# 65447          0.0342          0.5502         -0.0775 -1.6023 -0.0157  0.0069
# 12275          0.4682         -0.7061         -0.2210 -0.2402 -0.7037  0.0069
# 28410         -0.1947         -1.0229         -0.4270 -0.0524  0.0393  0.0069
# 15529         -0.2980          0.2603         -0.2208  1.8681  0.2388  2.9492
# ...               ...             ...             ...     ...     ...     ...
# 72551         -0.0595         -0.7591         -0.2210  0.6159 -0.4963  0.0069
# 58251          0.0910         -0.4316          0.0323 -0.2498 -0.1064  0.6512
# 17525         -0.0595         -0.7877          0.0016  0.0187 -1.8254  0.0069
# 71137         -0.1564         -0.3690         -0.2210  1.0102  0.3628  2.5240
# 77126          0.5768         -0.7591         -0.1959 -0.5679  0.0393  0.0069
#
# [17718 rows x 6 columns]

# %%
y_train
# Out:
# 15668    1
# 2310     1
# 23428    0
# 84090    1
# 6281     0
#         ..
# 65593    1
# 27849    0
# 578      0
# 67975    0
# 23572    0
# Name: activity, Length: 70870, dtype: int64

# %%
y_test
# Out:
# 36773    0
# 65447    1
# 12275    1
# 28410    0
# 15529    1
#         ..
# 72551    1
# 58251    1
# 17525    1
# 71137    1
# 77126    0
# Name: activity, Length: 17718, dtype: int64

# %% [markdown]
# ## Handle Imbalancing data using SMOTE

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

# %%
X_train_bal
# Out:
#        acceleration_x  acceleration_y  acceleration_z    gyro_x    gyro_y  \
# 0           -0.059500       -0.338300        0.074900  1.701200  0.947700
# 1           -0.059500       -0.759100       -0.221000 -0.695900  0.039300
# 2           -0.164500       -1.049000       -0.188700 -1.110400  0.263500
# 3           -0.059500       -0.759100       -0.221000  0.370800 -1.140600
# 4           -0.361300       -1.044000       -0.204500 -1.453600 -0.913500
# ...               ...             ...             ...       ...       ...
# 70875       -0.133461       -1.090919       -0.105191 -1.360435 -1.029982
# 70876       -0.238064       -0.764951       -0.111512 -1.012051  0.249766
# 70877        0.325781       -0.854436       -0.191064  0.910055  0.828290
# 70878        0.232957       -0.759100       -0.374173  1.816376 -0.809345
# 70879        0.228875       -1.059877       -0.244600  1.420927  0.240267
#
#          gyro_z
# 0      1.672500
# 1      0.006900
# 2      1.112300
# ...

# %%
y_train_bal
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 70875    0
# 70876    0
# 70877    0
# 70878    0
# 70879    0
# Name: activity, Length: 70880, dtype: int64

# %% [markdown]
# ### -Here we have scaled data to make it on Certain Range

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_bal)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.12935027,  0.32550686,  1.60981779,  1.78936712,  1.10474176,
#          1.35322409],
#        [-0.12935027, -0.48700021, -0.2796627 , -0.73123803,  0.01009683,
#         -0.66484174],
#        [-0.41658692, -1.04675733, -0.07340984, -1.1670942 ,  0.28026349,
#          0.67447741],
#        ...,
#        [ 0.92462083, -0.67108165, -0.08850373,  0.95746033,  0.96085009,
#          1.33382716],
#        [ 0.67069111, -0.48700021, -1.25775739,  1.91047759, -1.01254214,
#          1.80259765],
#        [ 0.65952414, -1.06775878, -0.4303622 ,  1.49465373,  0.2522673 ,
#          1.43674136]])

# %%
X_test_scaled
# Out:
# array([[-1.07887258, -0.90561126, -1.01719226,  0.79315448, -0.26127485,
#         -0.66484174],
#        [ 0.12697425,  2.04107845,  0.63666191, -1.68433824, -0.05617956,
#         -0.66484174],
#        [ 1.31421908, -0.38466448, -0.2796627 , -0.25205912, -0.88523692,
#         -0.66484174],
#        ...,
#        [-0.12935027, -0.54222288,  1.14175791,  0.02018012, -2.23691372,
#         -0.66484174],
#        [-0.39442867,  0.26622937, -0.2796627 ,  1.06276491,  0.39992249,
#          2.3849142 ],
#        [ 1.61130384, -0.48700021, -0.11938571, -0.59664312,  0.01009683,
#         -0.66484174]])

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train_scaled, y_train_bal)
# Out:
# LogisticRegression()

# %%
# Training Accuracy

# %%
y_train_pred = lr.predict(X_train_scaled)

# %%
f1_score(y_train_bal,y_train_pred)

# %%
y_pred = lr.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 0, 1, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,f1_score,classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[7993,  800],
#        [2108, 6817]], dtype=int64)

# %%
print("Accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.8358731233773563

# %%
print("Recall Score:",recall_score(y_test,y_pred))
# Out:
# Recall Score: 0.7638095238095238

# %%
print("Precision Score:",precision_score(y_test,y_pred))
# Out:
# Precision Score: 0.8949717736641722

# %%
print("F1 Score:",f1_score(y_test,y_pred))
# Out:
# F1 Score: 0.8242050538024422

# %%
print('\nClassification Report:\n',classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.91      0.85      8793
#            1       0.89      0.76      0.82      8925
#
#     accuracy                           0.84     17718
#    macro avg       0.84      0.84      0.84     17718
# weighted avg       0.84      0.84      0.84     17718

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

# %%
Svm_clf = SVC(kernel = 'rbf')

# %%
Svm_clf.fit(X_train_scaled, y_train_bal)
# Out:
# SVC()

# %%
y_pred = Svm_clf.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([0, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
from sklearn.metrics import classification_report,accuracy_score,f1_score

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.9501072355796365

# %%
print('F1 Score',f1_score(y_test,y_pred))
# Out:
# F1 Score 0.9501128668171558

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      8793
#            1       0.96      0.94      0.95      8925
#
#     accuracy                           0.95     17718
#    macro avg       0.95      0.95      0.95     17718
# weighted avg       0.95      0.95      0.95     17718

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train_scaled,y_train_bal)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,classification_report,f1_score

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.9636527824810927

# %%
print('F1 Score',f1_score(y_test,y_pred))
# Out:
# F1 Score 0.9635375382176424

# %%
print('\nClassification Report:\n',classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      8793
#            1       0.97      0.95      0.96      8925
#
#     accuracy                           0.96     17718
#    macro avg       0.96      0.96      0.96     17718
# weighted avg       0.96      0.96      0.96     17718

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_clf = DecisionTreeClassifier()

# %%
tree_clf.fit(X_train_scaled,y_train_bal)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = tree_clf.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,classification_report,f1_score

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.9666440907551642

# %%
print('F1 Score',f1_score(y_test,y_pred))
# Out:
# F1 Score 0.966892611058204

# %%
print('\nClassification Report:\n',classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      8793
#            1       0.97      0.97      0.97      8925
#
#     accuracy                           0.97     17718
#    macro avg       0.97      0.97      0.97     17718
# weighted avg       0.97      0.97      0.97     17718

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier()

# %%
rf_clf.fit(X_train_scaled,y_train_bal)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf_clf.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,classification_report,f1_score

# %%
print('Accuracy',accuracy_score(y_test,y_pred))
# Out:
# Accuracy 0.9800203183203522

# %%
print('F1 Score',f1_score(y_test,y_pred))
# Out:
# F1 Score 0.9800967052738109

# %%
print('\nClassification Report:\n',classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      8793
#            1       0.98      0.98      0.98      8925
#
#     accuracy                           0.98     17718
#    macro avg       0.98      0.98      0.98     17718
# weighted avg       0.98      0.98      0.98     17718

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

models = {
    "Logistic Regression": LogisticRegression(),
    "SVM": SVC(kernel='rbf'),
    "Random Forest": RandomForestClassifier(),
    "KNN": KNeighborsClassifier(),
    "Decision Tree":DecisionTreeClassifier()
}

results = {}

for name, model in models.items():
    model.fit(X_train_scaled,y_train_bal)
    y_pred = model.predict(X_test_scaled)
    results[name] = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average='weighted', zero_division=0),
        "Recall": recall_score(y_test, y_pred, average='weighted', zero_division=0),
        "F1 Score": f1_score(y_test, y_pred, average='weighted', zero_division=0)
    }

import pandas as pd
comparison_df = pd.DataFrame(results).T
print(comparison_df)
# Out:
#                      Accuracy  Precision    Recall  F1 Score
# Logistic Regression  0.835873   0.843526  0.835873  0.835065
# SVM                  0.950107   0.950210  0.950107  0.950107
# Random Forest        0.979907   0.979950  0.979907  0.979908
# KNN                  0.963653   0.963867  0.963653  0.963652
# Decision Tree        0.965797   0.965798  0.965797  0.965797

# %%
models = {
    "Logistic regresion":LogisticRegression(),
    "SVM": SVC(kernel = 'rbf'),
    "KNN": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier()
}

results = []

for name,model in models.items():
    if name in ['Logistic regresion','Svm_clf','knn']:
        model.fit(X_train_scaled,y_train_bal)
        y_pred = model.predict(X_test_scaled)
    else:
        model.fit(X_train_scaled,y_train_bal)
        y_pred = model.predict(X_test_scaled)

    acc = accuracy_score(y_test,y_pred)
    results.append({"Model":name,"Accuracy":round(acc,4)})

results_df = pd.DataFrame(results)

plt.figure(figsize=(10,6))
sns.barplot(data=results_df,x='Model',y='Accuracy',palette='viridis')
plt.title('Model Accuracy comparison',fontsize=16)
plt.ylim(0,1)
plt.ylabel('Accuracy Score')
plt.xticks(rotation = 45)
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = model.predict(X_test_scaled)
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=['Walking', 'Running']))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# %%
import pickle

# Save model
with open("random_forest_model.pkl", "wb") as f:
    pickle.dump(rf_clf, f)

# Save scaler
with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)
