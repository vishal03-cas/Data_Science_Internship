# %% [markdown]
# # 📊 Data Analysis Report for Rice Leaf Disease Dataset
#
# ---
#
# ## 1. 📂 Dataset Overview
#
# The dataset consists of **119 images** of rice leaves categorized into three classes:
#
# - **Bacterial Leaf Blight**: 40 images
# - **Brown Spot**: 40 images
# - **Leaf Smut**: 39 images
#
# These images are collected from infected rice plants, each showing distinct symptoms. The objective is to classify these images into the correct disease categories.
#
# ---
#
# ## 2. 🧾 Dataset Characteristics
#
# - **Small dataset size**: Only 119 images, which is limited for deep learning.
# - **Class distribution**: Nearly balanced (around 40 images per class).
# - **Image quality**: Varies in lighting, background, and leaf orientation.
# - **Image format**: RGB images with 3 color channels (important for disease spot detection).
#
# ---
#
# ## 3. ⚠️ Challenges with the Dataset
#
# - **Limited sample size** → Higher risk of overfitting.
# - **Variability** → Differences in angles, lighting, and background make learning harder.
# - **Visual similarity** → Some diseases look quite similar, leading to possible misclassification.
#
# ---
#
# ## 4. 🛠️ Data Preprocessing & Cleaning
#
# - **Resizing** → All images resized to a uniform size (e.g., 255x255 pixels).
# - **Normalization** → Pixel values scaled between 0 and 1.
# - **Shuffling and batching** → Applied for better training and to avoid bias.
#
# ---
#
# ## 5. 🔁 Data Augmentation
#
# To improve model performance and reduce overfitting, augmentation techniques were used:
#
# - Random **horizontal/vertical flips**
# - Random **rotations**
# - These simulate real-world variations and help the model generalize better.
#
# ---
#
# ## 6. 🔎 Exploratory Data Analysis (EDA)
#
# - **Class count visualization** → Checked if data is balanced.
# - **Sample visualization** → Displayed images from each class to understand appearance.
# - **Label verification** → Ensured correct labeling of images.
#
# ---
#
# ## 7. ✅ Summary & Insights
#
# - Dataset is small but usable for training with augmentation and preprocessing.
# - Data augmentation is **necessary** to improve learning and generalization.
# - Preprocessing brings uniformity to image inputs.
# - **Deep models or transfer learning** may be required due to visual similarity between disease classes.
#
# ---

# %% [markdown]
# ## Importing Libraries and Mount drive to Import Images dataset

# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %%
# set all the constants(hyperparameters)
BATCH_SIZE = 32
IMAGE_SIZE = 255
CHANNEL = 3
EPOCHS = 20
from google.colab import drive
drive.mount('/content/drive')

dataset = tf.keras.preprocessing.image_dataset_from_directory(
    directory='/content/drive/MyDrive/Data',  # or your actual path here
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 CHANNEL = 3
#       5 EPOCHS = 20
# ----> 6 from google.colab import drive
#       7 drive.mount('/content/drive')
#       9 dataset = tf.keras.preprocessing.image_dataset_from_directory(
#      10     directory='/content/drive/MyDrive/Data',  # or your actual path here
#      11     seed=123,
#    (...)
#      14     batch_size=BATCH_SIZE
#      15 )
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial leaf blight', 'Brown spot', 'Leaf smut']

# %% [markdown]
# ## Label :-
# #### This part shows the labels corresponding to the images in the batch. It's a 1D tensor with a shape of (32), indicating the label for each image in the batch. The labels seem to be integers, ranging from 0 to 2

# %%
for image_batch,label_batch in dataset.take(1):
    print("Image Batch Shape : ", image_batch.shape)
    print("Single Image : ", image_batch[0])
    print("Label Image numpy : ", label_batch.numpy)
# Out:
# Image Batch Shape :  (32, 255, 255, 3)
# Single Image :  tf.Tensor(
# [[[233.40111 218.40111 211.40111]
#   [233.15294 221.63528 215.63528]
#   [229.55293 218.77646 209.29411]
#   ...
#   [224.73552 207.73552 200.73552]
#   [225.74118 208.74118 201.74118]
#   [227.45874 210.45874 200.9764 ]]
#
#  [[232.42021 217.42021 210.42021]
#   [231.59999 218.59999 212.59999]
#   [232.77647 219.77647 211.77647]
#   ...
#   [225.77647 208.77647 201.77647]
#   [226.22353 209.22353 202.22353]
#   [227.57973 210.57973 202.57973]]
#
#  [[233.29411 220.29411 214.29411]
#   [232.55986 217.55986 212.55986]
#   [232.70589 217.70589 212.70589]
#   ...
#   [225.79234 208.79234 201.79234]
#   [226.52249 208.52249 204.52249]
#   [226.      212.      203.     ]]
#
#  ...
#
#  [[234.89479 220.16469 215.02974]
#   [234.11073 219.11073 214.11073]
#   [234.79237 219.79237 214.79237]
#   ...
#   [228.41498 210.12085 201.00323]
#   [229.1834  210.1834  203.88927]
#   [228.      209.      202.     ]]
#
#  [[234.1849  219.1849  214.1849 ]
#   [233.77649 219.22351 214.     ]
#   [235.      220.44702 215.22351]
#   ...
#   [230.77649 212.77649 202.77649]
#   [229.      210.      204.     ]
#   [230.55298 212.      204.77649]]
#
#  [[234.9188  219.9188  214.9188 ]
#   [233.4823  220.4823  214.4823 ]
#   [234.74115 221.74115 215.74115]
#   ...
#   [229.67096 211.67096 201.67096]
#   [229.88239 210.88239 203.88239]
#   [228.25885 211.25885 203.25885]]], shape=(255, 255, 3), dtype=float32)
# Label Image numpy :  <bound method _EagerTensorBase.numpy of <tf.Tensor: shape=(32,), dtype=int32, numpy=
# array([0, 1, 2, 2, 1, 0, 1, 0, 1, 1, 1, 2, 0, 1, 0, 1, 1, 1, 0, 0, 2, 2,
#        1, 2, 1, 1, 1, 2, 0, 2, 0, 0], dtype=int32)>>

# %%
len(class_names)
# Out:
# 3

# %% [markdown]
# # EDA :-
# ## Visualize some of the images from our dataset

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    # Code to process the first batch of images and labels
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ## Function to Split Dataset
# ### Dataset should be bifurcated into 3 subsets, namely:
#
# ##### Training: Dataset to be used while training
# ##### Validation: Dataset to be tested against while training
# ##### Test: Dataset to be tested against after we trained a model

# %%
total_batches = len(dataset)

train_size = max(1, int(0.7 * total_batches))
val_size = max(1, int(0.2 * total_batches))
test_size = total_batches - train_size - val_size

# Adjust again if needed
if test_size <= 0:
    test_size = 1
    train_size = total_batches - val_size - test_size

# Split dataset
train_ds = dataset.take(train_size)
val_ds = dataset.skip(train_size).take(val_size)
test_ds = dataset.skip(train_size + val_size)

# Print sizes
print(f"Train batches: {len(train_ds)}")
print(f"Validation batches: {len(val_ds)}")
print(f"Test batches: {len(test_ds)}")
# Out:
# Train batches: 2
# Validation batches: 1
# Test batches: 1

# %% [markdown]
# ##Building the Model
# #### Creating a Layer for Resizing and Normalization Before we feed our images to network, we should be resizing it to the desired size. Moreover, to improve model performance, we should normalize the image pixel value (keeping them in range 0 and 1 by dividing by 256). This should happen while training as well as inference. Hence we can add that as a layer in our Sequential Model.
#
# #### You might be thinking why do we need to resize (256,256) image to again (256,256). You are right we don't need to but this will be useful when we are done with the training and start using the model for predictions. At that time somone can supply an image that is not (256,256) and this layer will resize it

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(IMAGE_SIZE, IMAGE_SIZE), # Changed from layers.preprocessing.Resizing
  layers.Rescaling(1./255), # Changed from layers.preprocessing.Rescaling
])

# %% [markdown]
# # 📊 Data Augmentation Report
#
# ## 📝 Why Data Augmentation Was Used
#
# In this project, the dataset consists of only **119 total images** across **three classes**:
#
# - 40 images of **Bacterial Leaf Blight**
# - 40 images of **Brown Spot**
# - 39 images of **Leaf Smut**
#
# This is a very small dataset for training a deep learning model. If trained without augmentation, the model would likely:
#
# - Overfit to the small training set
# - Fail to generalize on new or unseen images
# - Show poor validation and test accuracy
#
# To overcome this, **data augmentation** was applied.

# %%
from tensorflow.keras import layers
import tensorflow as tf

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# %% [markdown]
# # Applying Data Augmentation to Train Dataset

# %%
for batch in val_ds.take(1):
    print("Validation batch found.")

for images, labels in val_ds.take(1):
    print(f"Validation batch shape: {images.shape}")

train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Validation batch found.
# Validation batch shape: (32, 255, 255, 3)

# %%
print(f"Train batches: {len(train_ds)}")
print(f"Validation batches: {len(val_ds)}")
# Out:
# Train batches: 2
# Validation batches: 1

# %% [markdown]
# # Model Architecture
#
# #### We use a CNN coupled with a Softmax activation in the output layer. We also add the initial layers for resizing, normalization and Data Augmentation.

# %%
n_classes = 3

model = models.Sequential([
    layers.InputLayer(input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNEL)),
    resize_and_rescale,
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

# %%
print(f"Length of train_ds: {len(train_ds)}")
print(f"Length of val_ds: {len(val_ds)}")
print(f"Length of test_ds: {len(test_ds)}")

if len(val_ds) == 0:
    print("Warning: val_ds is empty. Validation metrics will not be available.")
# Out:
# Length of train_ds: 2
# Length of val_ds: 1
# Length of test_ds: 1

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_2 (Sequential)       │ (None, 255, 255, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 253, 253, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 126, 126, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 124, 124, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 183,747 (717.76 KB)
#  Trainable params: 183,747 (717.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compiling the Model
# We use adam Optimizer, SparseCategoricalCrossentropy for losses, accuracy as a metric

# %%
from tensorflow.keras.optimizers import Nadam

optimizer = Nadam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',  # Use this if your labels are integers
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,  # Ensure val_ds is not None
    epochs=85,
    verbose=1,
)
# Out:
# Epoch 1/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.2604 - loss: 1.0996 - val_accuracy: 0.2188 - val_loss: 1.1102
# Epoch 2/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.2812 - loss: 1.1045 - val_accuracy: 0.2188 - val_loss: 1.1054
# Epoch 3/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.3333 - loss: 1.1042 - val_accuracy: 0.4688 - val_loss: 1.0967
# Epoch 4/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.4062 - loss: 1.0969 - val_accuracy: 0.3750 - val_loss: 1.0986
# Epoch 5/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.3854 - loss: 1.0949 - val_accuracy: 0.3750 - val_loss: 1.0921
# Epoch 6/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.3333 - loss: 1.0942 - val_accuracy: 0.3750 - val_loss: 1.0833
# Epoch 7/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.3854 - loss: 1.0911 - val_accuracy: 0.3750 - val_loss: 1.0845
# Epoch 8/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.3646 - loss: 1.0878 - val_accuracy: 0.3750 - val_loss: 1.0932
# Epoch 9/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.3854 - loss: 1.0755 - val_accuracy: 0.5938 - val_loss: 1.0738
# Epoch 10/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 4s/step - accuracy: 0.4271 - loss: 1.0776 - val_accuracy: 0.5000 - val_loss: 1.0480
# Epoch 11/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.4688 - loss: 1.0746 - val_accuracy: 0.5312 - val_loss: 1.0613
# Epoch 12/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.4375 - loss: 1.0621 - val_accuracy: 0.5312 - val_loss: 1.0438
# Epoch 13/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.4896 - loss: 1.0509 - val_accuracy: 0.5312 - val_loss: 0.9996
# Epoch 14/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.4271 - loss: 1.0510 - val_accuracy: 0.5938 - val_loss: 1.0219
# Epoch 15/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.4375 - loss: 1.0389 - val_accuracy: 0.5938 - val_loss: 0.9669
# Epoch 16/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.6250 - loss: 0.9711 - val_accuracy: 0.5625 - val_loss: 0.9779
# Epoch 17/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - accuracy: 0.5625 - loss: 0.9922 - val_accuracy: 0.5625 - val_loss: 0.9354
# Epoch 18/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step - accuracy: 0.5417 - loss: 0.9215 - val_accuracy: 0.6250 - val_loss: 0.8833
# Epoch 19/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.6667 - loss: 0.8228 - val_accuracy: 0.6250 - val_loss: 0.8735
# Epoch 20/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 7s/step - accuracy: 0.5312 - loss: 1.0101 - val_accuracy: 0.5938 - val_loss: 0.9743
# Epoch 21/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.5208 - loss: 0.9729 - val_accuracy: 0.6250 - val_loss: 0.8697
# Epoch 22/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - accuracy: 0.6146 - loss: 0.8654 - val_accuracy: 0.6250 - val_loss: 0.8853
# Epoch 23/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.6250 - loss: 0.8680 - val_accuracy: 0.5938 - val_loss: 0.9058
# Epoch 24/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.6458 - loss: 0.8357 - val_accuracy: 0.5938 - val_loss: 0.8800
# Epoch 25/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 7s/step - accuracy: 0.6667 - loss: 0.8067 - val_accuracy: 0.5938 - val_loss: 0.9187
# Epoch 26/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.6562 - loss: 0.8259 - val_accuracy: 0.6250 - val_loss: 0.9282
# Epoch 27/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 25s 8s/step - accuracy: 0.6771 - loss: 0.7965 - val_accuracy: 0.5938 - val_loss: 0.8533
# Epoch 28/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - accuracy: 0.6458 - loss: 0.7807 - val_accuracy: 0.5938 - val_loss: 0.8941
# Epoch 29/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.5625 - loss: 0.7903 - val_accuracy: 0.5938 - val_loss: 0.8651
# Epoch 30/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.6771 - loss: 0.7920 - val_accuracy: 0.5938 - val_loss: 0.9127
# Epoch 31/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.5729 - loss: 0.7947 - val_accuracy: 0.5938 - val_loss: 0.9040
# Epoch 32/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.6875 - loss: 0.7440 - val_accuracy: 0.6250 - val_loss: 0.8450
# Epoch 33/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step - accuracy: 0.6667 - loss: 0.7049 - val_accuracy: 0.6250 - val_loss: 0.8143
# Epoch 34/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.6875 - loss: 0.6855 - val_accuracy: 0.6250 - val_loss: 0.7675
# Epoch 35/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.6354 - loss: 0.7345 - val_accuracy: 0.6875 - val_loss: 0.7344
# Epoch 36/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.6771 - loss: 0.6882 - val_accuracy: 0.6562 - val_loss: 0.8092
# Epoch 37/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.7292 - loss: 0.6668 - val_accuracy: 0.5938 - val_loss: 0.9365
# Epoch 38/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.6250 - loss: 0.7396 - val_accuracy: 0.7188 - val_loss: 0.6936
# Epoch 39/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step - accuracy: 0.6771 - loss: 0.6778 - val_accuracy: 0.7500 - val_loss: 0.6945
# Epoch 40/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.7083 - loss: 0.6501 - val_accuracy: 0.7500 - val_loss: 0.7310
# Epoch 41/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - accuracy: 0.7292 - loss: 0.6446 - val_accuracy: 0.6562 - val_loss: 0.7500
# Epoch 42/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.6771 - loss: 0.6498 - val_accuracy: 0.7188 - val_loss: 0.6519
# Epoch 43/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.7292 - loss: 0.6431 - val_accuracy: 0.6562 - val_loss: 0.8424
# Epoch 44/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 7s/step - accuracy: 0.7812 - loss: 0.6242 - val_accuracy: 0.7500 - val_loss: 0.7185
# Epoch 45/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.7083 - loss: 0.6101 - val_accuracy: 0.6875 - val_loss: 0.6826
# Epoch 46/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - accuracy: 0.6667 - loss: 0.7005 - val_accuracy: 0.5625 - val_loss: 0.7178
# Epoch 47/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.6979 - loss: 0.6594 - val_accuracy: 0.8125 - val_loss: 0.6055
# Epoch 48/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.7188 - loss: 0.6474 - val_accuracy: 0.7188 - val_loss: 0.7138
# Epoch 49/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.7188 - loss: 0.6222 - val_accuracy: 0.7812 - val_loss: 0.6429
# Epoch 50/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.7917 - loss: 0.5809 - val_accuracy: 0.6875 - val_loss: 0.7095
# Epoch 51/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step - accuracy: 0.7500 - loss: 0.5799 - val_accuracy: 0.7812 - val_loss: 0.6041
# Epoch 52/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - accuracy: 0.7500 - loss: 0.5745 - val_accuracy: 0.7812 - val_loss: 0.6009
# Epoch 53/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.7917 - loss: 0.5620 - val_accuracy: 0.8125 - val_loss: 0.5697
# Epoch 54/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 6s/step - accuracy: 0.7708 - loss: 0.5643 - val_accuracy: 0.6562 - val_loss: 0.7690
# Epoch 55/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step - accuracy: 0.6354 - loss: 0.7322 - val_accuracy: 0.7188 - val_loss: 0.6007
# Epoch 56/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.7188 - loss: 0.5635 - val_accuracy: 0.7188 - val_loss: 0.6817
# Epoch 57/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.7604 - loss: 0.5582 - val_accuracy: 0.8438 - val_loss: 0.5447
# Epoch 58/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - accuracy: 0.7708 - loss: 0.5054 - val_accuracy: 0.7812 - val_loss: 0.5240
# Epoch 59/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.8125 - loss: 0.5246 - val_accuracy: 0.7812 - val_loss: 0.5427
# Epoch 60/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.8125 - loss: 0.5026 - val_accuracy: 0.7812 - val_loss: 0.5739
# Epoch 61/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.8542 - loss: 0.4695 - val_accuracy: 0.7812 - val_loss: 0.5147
# Epoch 62/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.7083 - loss: 0.5590 - val_accuracy: 0.5312 - val_loss: 1.3541
# Epoch 63/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.6146 - loss: 0.9229 - val_accuracy: 0.7812 - val_loss: 0.5766
# Epoch 64/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step - accuracy: 0.8021 - loss: 0.5037 - val_accuracy: 0.8125 - val_loss: 0.5288
# Epoch 65/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.8438 - loss: 0.4751 - val_accuracy: 0.8125 - val_loss: 0.5188
# Epoch 66/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step - accuracy: 0.7812 - loss: 0.5059 - val_accuracy: 0.8125 - val_loss: 0.5132
# Epoch 67/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 7s/step - accuracy: 0.8333 - loss: 0.4452 - val_accuracy: 0.8125 - val_loss: 0.4872
# Epoch 68/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 7s/step - accuracy: 0.8750 - loss: 0.4045 - val_accuracy: 0.8438 - val_loss: 0.4801
# Epoch 69/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - accuracy: 0.8750 - loss: 0.3875 - val_accuracy: 0.8125 - val_loss: 0.4984
# Epoch 70/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.8646 - loss: 0.3793 - val_accuracy: 0.7500 - val_loss: 0.6487
# Epoch 71/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 5s/step - accuracy: 0.7292 - loss: 0.6347 - val_accuracy: 0.7188 - val_loss: 0.5857
# Epoch 72/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.8021 - loss: 0.4707 - val_accuracy: 0.7188 - val_loss: 0.6490
# Epoch 73/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 7s/step - accuracy: 0.8021 - loss: 0.4719 - val_accuracy: 0.6562 - val_loss: 0.8076
# Epoch 74/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 15s/step - accuracy: 0.7396 - loss: 0.5180 - val_accuracy: 0.7812 - val_loss: 0.5734
# Epoch 75/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 7s/step - accuracy: 0.8229 - loss: 0.3708 - val_accuracy: 0.8125 - val_loss: 0.5751
# Epoch 76/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 5s/step - accuracy: 0.8854 - loss: 0.3379 - val_accuracy: 0.8125 - val_loss: 0.6057
# Epoch 77/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - accuracy: 0.8750 - loss: 0.2938 - val_accuracy: 0.8125 - val_loss: 0.5856
# Epoch 78/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.8958 - loss: 0.2752 - val_accuracy: 0.7500 - val_loss: 0.7153
# Epoch 79/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step - accuracy: 0.8021 - loss: 0.4996 - val_accuracy: 0.7500 - val_loss: 0.6083
# Epoch 80/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 7s/step - accuracy: 0.8229 - loss: 0.3889 - val_accuracy: 0.7500 - val_loss: 0.6311
# Epoch 81/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.8854 - loss: 0.2925 - val_accuracy: 0.7812 - val_loss: 0.6575
# Epoch 82/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 5s/step - accuracy: 0.9583 - loss: 0.2143 - val_accuracy: 0.8125 - val_loss: 0.6927
# Epoch 83/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.8854 - loss: 0.2374 - val_accuracy: 0.7500 - val_loss: 0.8328
# Epoch 84/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 7s/step - accuracy: 0.7708 - loss: 0.6057 - val_accuracy: 0.7188 - val_loss: 0.7398
# Epoch 85/85
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - accuracy: 0.7812 - loss: 0.5531 - val_accuracy: 0.7188 - val_loss: 0.7115

# %%
scores = model.evaluate(test_ds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.9130 - loss: 0.3154

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Plotting the Accuracy and Loss Curves

# %%
print(history)
print(history.params)
print(history.history.keys())
# Out:
# <keras.src.callbacks.history.History object at 0x7873ce8bf190>
# {'verbose': 1, 'epochs': 85, 'steps': 2}
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
print("Available history keys:", history.history.keys())
if len(val_ds) == 0:
    print("⚠️ Warning: Validation dataset is empty. No validation accuracy/loss will be recorded.")
history.history['loss'][:5] # show loss for first 5 epochs
# Out:
# Available history keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# [1.099749207496643,
#  1.1028944253921509,
#  1.1085740327835083,
#  1.0966577529907227,
#  1.0961778163909912]

# %%
acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']

loss = history.history['loss']
# val_loss = history.history['val_loss']

# %%
acc = history.history['accuracy']
val_acc = history.history.get('val_accuracy')  # use .get() in case it's None

loss = history.history['loss']
val_loss = history.history.get('val_loss')

epochs_range = range(len(acc))  # will automatically match the number of trained epochs

plt.figure(figsize=(12, 6))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
if val_acc:
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
if val_loss:
    plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %% [markdown]
# # Run prediction on a sample image

# %%
model = tf.keras.models.load_model('model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Bacterial leaf blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 849ms/step
# predicted label: Bacterial leaf blight

# %% [markdown]
# # 🧠 Inference Report
#
# ## 📝 Why Inference Was Used
#
# After training the model on a small dataset, inference was done to check how well the model predicts new, unseen images.
#
# ## 🔍 What Inference Does
#
# - Predicts classes for new images using the trained model
# - Provides confidence scores for each prediction
# - Helps verify model accuracy on test data
#
# ## ✅ Benefits of Inference
#
# - Confirms model’s real-world performance
# - Shows actual vs predicted results
# - Measures prediction confidence

# %% [markdown]
# ## Function for inference

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
